# %% [markdown]
# <a href="https://colab.research.google.com/github/xyfuu/DailyChallanges/blob/main/X_Web_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tweepy

# %%
import tweepy

BEARER_TOKEN = "AAAAAAAAAAAAAAAAAAAAA***********************************************************************" #secret wlee

client = tweepy.Client(bearer_token=BEARER_TOKEN)

# %%
query = "trump -is:retweet lang:en"
tweets = client.search_recent_tweets(query=query, max_results=10)

for tweet in tweets.data:
    print(tweet.text)
# Out:
# @TRUMP_ARMY_ It’s a 10 !
# @angela4LNCChair @realDonaldTrump Any libertarian who didn't vote for Trump is a fucking retard.
# Trump hates the constitution https://t.co/k7ND0eQtjc
# @stillgray F no. He isn't someone Trump would hang out.
# On Donald Trump's Inauguration Day in 2025, several major actions were taken:
#
# - **Pardons**: Trump issued pardons for approximately 1,500 individuals involved in the January 6, 2021, Capitol riot. This move was widely discussed, with some seeing it as fulfilling campaign… https://t.co/nXGNQjgT2M
# I've genuinely never heard anything good about Donald Trump in my entire life why are people voting for him?
#
# Like everything he's doing just sounds bad for EVERYONE and doesn't benefit a single person other than his own personal beliefs
# "I ask you to have mercy"
# Trump criticizes church service after bishop makes plea for immigrants https://t.co/TJtBEjIuY7 via @YouTube
# ...

# %%
import pandas as pd
# Store tweets
tweet_data = [{"Tweet": tweet.text} for tweet in tweets.data]

# Convert to CSV
df = pd.DataFrame(tweet_data)
df.to_csv("tweets.csv", index=False)

print("Tweets saved to tweets.csv")
# Out:
# Tweets saved to tweets.csv
